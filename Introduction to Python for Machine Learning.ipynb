# %%
import pandas as pd
import numpy as np

# %%
url = "C:\\Users\\lenovo\\Downloads\\FoodBalanceSheets_E_Africa_NOFLAG.csv"

# %%
df = pd.read_csv(url, encoding = "latin-1")

# %%
df.describe()
#df.head() #least correlation with ‘Element Code’
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.groupby("Item")["Y2015"].sum() 
#sum of Wine produced in 2015
# Out:
# Item
# Alcohol, Non-Food        2180.00
# Alcoholic Beverages     98783.72
# Animal Products         11811.73
# Animal fats            200675.72
# Apples and products     10559.15
#                          ...
# Vegetables, Other      158104.08
# Vegetal Products       107064.17
# Wheat and products     234710.51
# Wine                     4251.81
# Yams                   203151.78
# Name: Y2015, Length: 119, dtype: float64

# %%
df.groupby("Item")["Y2018"].sum()
#sum of Wine produced in 2018
# Out:
# Item
# Alcohol, Non-Food        2293.00
# Alcoholic Beverages     97847.27
# Animal Products         11578.61
# Animal fats            269648.27
# Apples and products      9640.51
#                          ...
# Vegetables, Other      163987.21
# Vegetal Products       107775.39
# Wheat and products     242645.19
# Wine                     4039.32
# Yams                   221272.09
# Name: Y2018, Length: 119, dtype: float64

# %%
df1 = pd.DataFrame(df)
df1
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df.shape
# Out:
# (60943, 12)

# %%
#question 7

lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

#create a pandas DataFrame using this list
pd.DataFrame(lst, columns = col, index = [i for i in range(1,4)])
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
print(df["Element"].unique()) 
print(df["Element"] == "Protein supply quantity(g/capita/day)")
# Out:
# ['Total Population - Both sexes' 'Domestic supply quantity'
#  'Food supply (kcal/capita/day)' 'Protein supply quantity (g/capita/day)'
#  'Fat supply quantity (g/capita/day)' 'Production' 'Import Quantity'
#  'Stock Variation' 'Export Quantity' 'Feed' 'Seed' 'Losses' 'Processing'
#  'Other uses (non-food)' 'Residuals' 'Food'
#  'Food supply quantity (kg/capita/yr)' 'Tourist consumption']
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 60938    False
# 60939    False
# 60940    False
# 60941    False
# 60942    False
# Name: Element, Length: 60943, dtype: bool

# %%
df2 = df.groupby('Element').agg(['count'])
df2

df3 = df2.groupby(df['Area'] == 'Madagascar').count()
df3
# Out:
#                                        Area Code  Area Item Code  Item  \
#                                            count count     count count
# Element
# Domestic supply quantity                    5295  5295      5295  5295
# Export Quantity                             4403  4403      4403  4403
# Fat supply quantity (g/capita/day)          5023  5023      5023  5023
# Feed                                        1319  1319      1319  1319
# Food                                        4941  4941      4941  4941
# Food supply (kcal/capita/day)               5014  5014      5014  5014
# Food supply quantity (kg/capita/yr)         4905  4905      4905  4905
# Import Quantity                             5139  5139      5139  5139
# Losses                                      2009  2009      2009  2009
# Other uses (non-food)                       1732  1732      1732  1732
# Processing                                  2010  2010      2010  2010
# ...

# %%
df.groupby("Area")['Y2017'].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
df.groupby(df["Element"] == 'Stock Variation').sum()

#What year has the highest sum of Stock Variation
# Out:
#          Area Code  Item Code  Element Code       Y2014       Y2015  \
# Element
# False      7610981  152435083     211024093  7906336.30  7997429.24
# True        571566   11329527      21464704    58749.83    34910.99
#
#               Y2016       Y2017       Y2018
# Element
# False    8079332.53  8321412.28  8534052.05
# True       33140.12    54316.91    20577.91

# %%
df.groupby("Area")["Y2017"].sum()

#Which of these Areas had the 7th lowest sum in 2017
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
df.describe() #mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
df.groupby(df["Element"] == 'Processing').sum()
#What is the total number of the sum of Processing in 2017
# Out:
#          Area Code  Item Code  Element Code       Y2014       Y2015  \
# Element
# False      7910607  158414194     222175487  7682163.13  7744411.23
# True        271940    5350416      10313310   282923.00   287929.00
#
#               Y2016       Y2017       Y2018
# Element
# False    7831841.65  8082893.19  8246200.96
# True      280631.00   292836.00   308429.00

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-ce1543b3be47> in <module>
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
df.groupby("Area")["Y2017"].sum()

#Which of these Areas had the highest sum in 2017
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
df['Y2014'].isnull().sum() #total number and percentage of missing data in 2014
df['Y2014'].isnull().mean().round(3)
# Out:
# 0.026

# %%
y = [(2, 4), (7, 8), (1, 5, 9)] #How would you assign element 8 from the list to a variable x
x = y[2][-1]

# %%
df["Area"].nunique() #total number of unique countries in the dataset
# Out:
# 49

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'
